# %%
print('hello there')
# Out:
# hello there

# %%
from main import getCensus

# %%
c = getCensus(2019, shouldLoadFromExistingCache=True)
# Out:
# [INFO] 2021-01-02 20:28:25 -0500 [On-Disk Cache] creating cache for cache/2019/acs/acs1
# [INFO] 2021-01-02 20:28:25 -0500 [On-Disk Cache] setting up on disk cache

# %%
c.getGroups()
# Out:
# [INFO] 2021-01-02 20:28:26 -0500 [On-Disk Cache] cache hit for cache/2019/acs/acs1/groups.csv
#       Unnamed: 0    code                                        description
# 0              0  B17015  POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILI...
# 1              1  B18104                 SEX BY AGE BY COGNITIVE DIFFICULTY
# 2              2  B17016  POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILI...
# 3              3  B18105                SEX BY AGE BY AMBULATORY DIFFICULTY
# 4              4  B17017  POVERTY STATUS IN THE PAST 12 MONTHS BY HOUSEH...
# ...          ...     ...                                                ...
# 1371        1371  B09019  HOUSEHOLD TYPE (INCLUDING LIVING ALONE) BY REL...
# 1372        1372  B99132    ALLOCATION OF FERTILITY OF WOMEN 15 TO 50 YEARS
# 1373        1373  B09010  RECEIPT OF SUPPLEMENTAL SECURITY INCOME (SSI),...
# 1374        1374  C03001       HISPANIC OR LATINO ORIGIN BY SPECIFIC ORIGIN
# ...

# %%
c.getAllVariables()
# Out:
# [INFO] 2021-01-02 20:28:33 -0500 [Variable Repository] This is a costly operation, and may take time
# [INFO] 2021-01-02 20:28:33 -0500 [On-Disk Cache] cache hit for cache/2019/acs/acs1/variables/B17015.csv
# [INFO] 2021-01-02 20:28:33 -0500 [On-Disk Cache] cache hit for cache/2019/acs/acs1/variables/B18104.csv
# [INFO] 2021-01-02 20:28:33 -0500 [On-Disk Cache] cache hit for cache/2019/acs/acs1/variables/B17016.csv
# [INFO] 2021-01-02 20:28:33 -0500 [On-Disk Cache] cache hit for cache/2019/acs/acs1/variables/B18105.csv
# [INFO] 2021-01-02 20:28:33 -0500 [On-Disk Cache] cache hit for cache/2019/acs/acs1/variables/B17017.csv
# [INFO] 2021-01-02 20:28:33 -0500 [On-Disk Cache] cache hit for cache/2019/acs/acs1/variables/B18106.csv
# [INFO] 2021-01-02 20:28:33 -0500 [On-Disk Cache] cache hit for cache/2019/acs/acs1/variables/B17018.csv
# [INFO] 2021-01-02 20:28:33 -0500 [On-Disk Cache] cache hit for cache/2019/acs/acs1/variables/B18107.csv
# ...

# %%
c.getAllVariables()
# Out:
#      Unnamed: 0          code groupCode  \
# 0             0  B17015_047MA    B17015
# 1             1  B17015_047EA    B17015
# 2             2  B17015_046EA    B17015
# 3             3  B17015_046MA    B17015
# 4             4  B17015_045EA    B17015
# ..          ...           ...       ...
# 183         183  B17015_031EA    B17015
# 184         184  B17015_030MA    B17015
# 185         185  B17015_030EA    B17015
# 186         186  B17015_040MA    B17015
# 187         187  B17015_040EA    B17015
#
#                                                concept  \
# 0    POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILI...
# 1    POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILI...
# 2    POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILI...
# 3    POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILI...
# 4    POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILI...
# ..                                                 ...
# 183  POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILI...
# ...

# %%
len(c.variableCodes)
# Out:
# 189

# %%
from pprint import pprint

# %%
pprint(c.variableCodes['B17015_047MA'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c3db8dc46557> in <module>
# ----> 1 pprint(c.variableCodes['B17015_047MA'])
#
# TypeError: 'CodeSet' object is not subscriptable
